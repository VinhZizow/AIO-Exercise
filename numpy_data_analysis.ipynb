# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/gdrive/MyDrive/AIO - files/advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data = df.to_numpy()
data
# Out:
# array([[230.1,  37.8,  69.2,  22.1],
#        [ 44.5,  39.3,  45.1,  10.4],
#        [ 17.2,  45.9,  69.3,  12. ],
#        [151.5,  41.3,  58.5,  16.5],
#        [180.8,  10.8,  58.4,  17.9],
#        [  8.7,  48.9,  75. ,   7.2],
#        [ 57.5,  32.8,  23.5,  11.8],
#        [120.2,  19.6,  11.6,  13.2],
#        [  8.6,   2.1,   1. ,   4.8],
#        [199.8,   2.6,  21.2,  15.6],
#        [ 66.1,   5.8,  24.2,  12.6],
#        [214.7,  24. ,   4. ,  17.4],
#        [ 23.8,  35.1,  65.9,   9.2],
#        [ 97.5,   7.6,   7.2,  13.7],
#        [204.1,  32.9,  46. ,  19. ],
#        [195.4,  47.7,  52.9,  22.4],
#        [ 67.8,  36.6, 114. ,  12.5],
#        [281.4,  39.6,  55.8,  24.4],
#        [ 69.2,  20.5,  18.3,  11.3],
#        [147.3,  23.9,  19.1,  14.6],
#        [218.4,  27.7,  53.4,  18. ],
#        [237.4,   5.1,  23.5,  17.5],
#        [ 13.2,  15.9,  49.6,   5.6],
#        [228.3,  16.9,  26.2,  20.5],
#        [ 62.3,  12.6,  18.3,   9.7],
# ...

# %%
sales_data = data[:, 3]
sale_max = np.max(sales_data)
sale_index = np.argmax(sales_data)
tv_mean = data[:, 0].mean()
sale_counter_over20 = np.sum(data[:, 3]>=20.0)

test = data[:, 3]
test >= 20.0

sale_max, sale_index, tv_mean, sale_counter_over20
# Out:
# (27.0, 175, 147.0425, 40)

# %%
sales_data = data[:, 3]
sales_over15 = sales_data>=15.0

radio_data = data[:, 1]
radio_cond = radio_data * sales_over15
radio_mean = np.sum(radio_cond)/np.sum(sales_over15)

radio_mean
# Out:
# 26.222935779816517

# %%
news_data = data[:, 2]
news_mean = news_data.mean()
news_cond = news_data >= news_mean

sales_data = data[:, 3]
sales_cond = sales_data * news_cond
sales_sum = np.sum(sales_cond)

sales_sum
# Out:
# 1405.1

# %%
sales_data = data[:, 3]
sales_mean = sales_data.mean()
score_sales = np.where(sales_data < sales_mean, "Bad",
                       np.where(sales_data > sales_mean, "Good", "Avarage"))
score_sales[7:10]
# Out:
# array(['Bad', 'Bad', 'Good'], dtype='<U7')

# %%
sales_data = data[:, 3]
sales_mean = sales_data.mean()
subb_mean = sales_data - sales_mean
sub_abs = abs(sales_data - sales_mean)
avg_id = np.argmin(sub_abs)
sales_avg = sales_data[avg_id]
score_sales = np.where(sales_data < sales_mean, "Bad",
                       np.where(sales_data > sales_mean, "Good", "Avarage"))
score_sales[7:10]
# Out:
# array(['Bad', 'Bad', 'Good'], dtype='<U7')
